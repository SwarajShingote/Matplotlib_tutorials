# %%
# Plotting a time series
# Basics of datetime, timedelta, dates module
# to_datetime() creates data in the form of DD-MM-YY
# plt.plot_date() plot a graph with 2 para 
# plt.gcf().autofmt_xdate() autoformats the x axis (gcf=get current figure)
# date_format = mpl_dates.DateFormatter('%b,%d %Y')
# Above line formats date in the form (May,01,2019)
# plt.gca().xaxis.set_major_formatter(date_format)
# autoformats the x axis (gca=get current axis)

# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime , timedelta
from matplotlib import dates as mpl_dates


plt.style.use('seaborn')

# dates = [
#     datetime(2019, 5, 24),
#     datetime(2019, 5, 25),
#     datetime(2019, 5, 26),
#     datetime(2019, 5, 27),
#     datetime(2019, 5, 28),
#     datetime(2019, 5, 29),
#     datetime(2019, 5, 30)
# ]

# y = [0, 1, 3, 4, 6, 5, 7]


data = pd.read_csv('Code_snippet_master/data_timeseries.csv')
#print(data)
price_date = data['Date']
price_close = data['Close']
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date',inplace=True)

# plt.plot_date(dates,y,linestyle='solid')
# plt.gcf().autofmt_xdate()

plt.plot_date(price_date,price_close,linestyle='solid')

plt.gcf().autofmt_xdate()


date_format = mpl_dates.DateFormatter('%b,%d %Y')

plt.gca().xaxis.set_major_formatter(date_format)



plt.title("Bitcoin Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price")

plt.tight_layout()
plt.show()
